# %% [markdown]
# Week 4:
# How to Run Linear Regression:

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LinearRegression

# %%
import statsmodels.api as sm

# %%
# Sample data
X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)  # Reshape for sklearn
y = np.array([2, 4, 5, 4, 5])

# %%
model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)

# %%
# Print coefficients
print(f"Slope (m): {model.coef_[0]}")
print(f"Intercept (b): {model.intercept_}")
# Out:
# Slope (m): 0.6000000000000003
# Intercept (b): 2.1999999999999993

# %%
# Plot
plt.scatter(X, y, color='blue', label='Data points')
plt.plot(X, y_pred, color='red', label='Regression Line')
plt.legend()
plt.show()

# %% [markdown]
# Linear Regrestion using StatsModel

# %%
# Adding a constant for the intercept term
X_sm = sm.add_constant(X) 

# Fit the model
model_sm = sm.OLS(y, X_sm).fit()

# Print summary
print(model_sm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.600
# Model:                            OLS   Adj. R-squared:                  0.467
# Method:                 Least Squares   F-statistic:                     4.500
# Date:                Tue, 11 Feb 2025   Prob (F-statistic):              0.124
# Time:                        21:19:59   Log-Likelihood:                -5.2598
# No. Observations:                   5   AIC:                             14.52
# Df Residuals:                       3   BIC:                             13.74
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.2000      0.938      2.345      0.101      -0.785       5.185
# x1             0.6000      0.283      2.121      0.124      -0.300       1.500
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.017
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.570
# Skew:                           0.289   Prob(JB):                        0.752
# Kurtosis:                       1.450   Cond. No.                         8.37
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /Users/kahkeshanhijazi/Library/Python/3.9/lib/python/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "

# %% [markdown]
# Linear Regression using numpy:

# %%
# Compute slope (m) and intercept (b) using least squares
m, b = np.polyfit(X.flatten(), y, 1)

# Generate predictions
y_pred = m * X + b

print(f"Slope (m): {m}")
print(f"Intercept (b): {b}")
# Out:
# Slope (m): 0.6
# Intercept (b): 2.199999999999999
